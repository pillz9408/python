# %% [markdown]
# # seaborn
#  - 시각화를 쉽게 만들어주는 라이브러리의 한 종류

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import font_manager,rc
font_name = font_manager.FontProperties(fname = 'C:/Windows/Fonts/malgun.ttf').get_name()
rc('font',family = font_name)

# %%
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### box plot
#  - outlier 값을 확인하기 용이
#  - 아래선 : 최솟값
#  - 윗선: 최대값
#  - 점 : outlier
#  - 박스 내부 가로선 : 중앙값
#  - 박스 : 분포.. (1사분위~3사분위수) = 사분위수 범위

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='day',y='total_bill',data=tips)
plt.show()
# 아래선 : 최솟값
# 윗선: 최대값
# 점 : outlier
# 박스 내부 가로선 : 중앙값
# 박스 : 분포.. (1사분위~3사분위수) = 사분위수 범위

# %%
# 흡연자, 비흡연자 데이터 구분
# hue= 데이터 추가 구분(in legend)
# palette : 색상 지정
plt.figure(figsize=(8,6))
sns.boxplot(x='day',y='total_bill',data=tips,hue='smoker',palette='Set3')
plt.show()

# %% [markdown]
# ### 펭귄 데이터

# %%
penguins=sns.load_dataset('penguins')
penguins.head(7)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
# 6  Adelie  Torgersen            38.9           17.8              181.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female
# 5       3650.0    Male
# 6       3625.0  Female

# %% [markdown]
# ### Histplot :히스토그램 출력 plot

# %%
sns.histplot(data=penguins,x='flipper_length_mm', hue='species')
plt.show()

# %%
# 데이터가 겹치지 않게 : multiple = 'stack'
sns.histplot(data=penguins,x='flipper_length_mm', hue='species',multiple='stack')
plt.show()

# %% [markdown]
# ### displot: distribution 을 여러 subplot 으로 나누어 출력

# %%
#displot: distribution 을 여러 subplot 으로 나누어 출력
sns.displot(data=penguins,x='flipper_length_mm', hue='species',col='species')
plt.show()

# %% [markdown]
# ### countplot : 범주형 속성을 가지는 데이터의 히스토그램

# %%
# countplot : 범주형 속성을 가지는 데이터의 히스토그램
sns.countplot(data=penguins,y='species',hue='sex')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# boxplot 그리기
# 종별로 몸무게 분포 확인
sns.boxplot(data=penguins,x='species',y='body_mass_g',hue='sex',palette='Set3')
plt.show()

# %% [markdown]
# ### violinplot
#  - 전체 데이터 분포 확인에 용이

# %%
sns.violinplot(data=penguins,x='species',y='body_mass_g',hue='sex',palette='Set3')
plt.show()

# %% [markdown]
# ### Lineplot

# %%
sns.lineplot(data=penguins,x='bill_depth_mm',y='bill_length_mm',hue='species')
plt.show()

# %% [markdown]
# ### scatterplot

# %%
sns.scatterplot(data=penguins,x='bill_depth_mm',y='bill_length_mm',hue='sex')
plt.show()

# %% [markdown]
# ### pairplot
#  - 데이터 각 feature들 사이의 모든 관계를 표시해주는 plot

# %%
sns.pairplot(data=penguins,hue='species',palette='Set1')
plt.show()

# %% [markdown]
# ### correlation
#  - 관계성 시각화
#  - heatmap

# %%
# correlation
corr = penguins.corr()

# %%
# heatmap
sns.heatmap(corr)
# Out:
# c:\Users\user\anaconda\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# <AxesSubplot:>
# c:\Users\user\anaconda\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # bike파일

# %%
bike = pd.read_csv('./bike.csv',encoding='utf-8')
bike.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
bike.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
bike.shape
# Out:
# (10886, 12)

# %%
bike.describe
# Out:
# <bound method NDFrame.describe of                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %%
corr = bike.corr()
sns.heatmap(corr)
# Out:
# c:\Users\user\anaconda\lib\site-packages\seaborn\utils.py:95: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.draw()
# <AxesSubplot:>
# c:\Users\user\anaconda\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.scatterplot(data=bike,x='registered',y='temp',hue='season')
plt.show()

# %%
# Datetime을 날짜로 인식
bike['datetime']=pd.to_datetime(bike['datetime'])

# %%
bike.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
bike.info
# Out:
# <bound method DataFrame.info of                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-01 00:00:00       1        0           0        1   9.84
# 1     2011-01-01 01:00:00       1        0           0        1   9.02
# 2     2011-01-01 02:00:00       1        0           0        1   9.02
# 3     2011-01-01 03:00:00       1        0           0        1   9.84
# 4     2011-01-01 04:00:00       1        0           0        1   9.84
# ...                   ...     ...      ...         ...      ...    ...
# 10881 2012-12-19 19:00:00       4        0           1        1  15.58
# 10882 2012-12-19 20:00:00       4        0           1        1  14.76
# 10883 2012-12-19 21:00:00       4        0           1        1  13.94
# 10884 2012-12-19 22:00:00       4        0           1        1  13.94
# 10885 2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %%
# datetime 을 연,월,일,시,분,초로 나눠보자.
bike['year'] = bike['datetime'].dt.year
bike['month'] = bike['datetime'].dt.month
bike['day'] = bike['datetime'].dt.day
bike['hour'] = bike['datetime'].dt.hour

# %%
# dayofweek 는 요일을 가져오는 명령어
# 월(0)~일(6)
bike['dayofweek'] = bike['datetime'].dt.dayofweek

# %%
bike.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  year  month  day  hour  \
# 0        81        0.0       3          13     16  2011      1    1     0
# 1        80        0.0       8          32     40  2011      1    1     1
# 2        80        0.0       5          27     32  2011      1    1     2
# 3        75        0.0       3          10     13  2011      1    1     3
# 4        75        0.0       0           1      1  2011      1    1     4
#
#    dayofweek
# 0          5
# 1          5
# 2          5
# 3          5
# ...

# %%
# year 별 자전거 수요량
# month 별 자전거 수요량
# day 별 자전거 수요량
# season별 자전거 수요량

# %%
sns.barplot(data=bike,x='year',y='count')
plt.show()

# %%
sns.barplot(data=bike,x='month',y='count')
plt.show()

# %%
sns.barplot(data=bike,x='day',y='count')
plt.show()

# %%
sns.barplot(data=bike,x='season',y='count')
plt.show()

# %%
sns.barplot(data=bike,x='hour',y='count')
plt.show()

# %%
# 시간대별 pointplot
sns.pointplot(data=bike, x='hour',y='count',hue='workingday')
plt.show()

# %%
sns.pointplot(data=bike, x='hour',y='count',hue='holiday')
plt.show()

# %%
sns.pointplot(data=bike, x='hour',y='count',hue='weather')
plt.show()

# %% [markdown]
# ### fig,(ax1,ax2,ax3) = plt.subplots(ncols=3,figsize=(12,5))
#     - 여러개 한번에 그리기
#     - alpha= 0.5 : 투명도 설정

# %%
# 온도, 습도, 바람세기
fig,(ax1,ax2,ax3) = plt.subplots(ncols=3,figsize=(12,5))

sns.scatterplot(data= bike, x='windspeed',y='count',ax=ax1,alpha=0.5) 
sns.scatterplot(data= bike, x='temp',y='count',ax=ax2)
sns.scatterplot(data= bike, x='humidity',y='count',ax=ax3)
plt.show()

# %%
len(bike[bike['windspeed']==0])
# Out:
# 1313

# %%
# 이상치 확인
# temp 칼럼부터 count 칼럼까지 각각 boxplot 그리기
# 단, 6개의 boxplot을 한번에 출력!
fig,(ax1,ax2,ax3,ax4,ax5,ax6) = plt.subplots(ncols=6,figsize=(30,10))
sns.boxplot(data= bike, x='windspeed',ax=ax1)
sns.boxplot(data= bike, x='temp',ax=ax2)
sns.boxplot(data= bike, x='humidity',ax=ax3)
sns.boxplot(data= bike, x='atemp',ax=ax4)
sns.boxplot(data= bike, x='casual',ax=ax5)
sns.boxplot(data= bike, x='registered',ax=ax6)
plt.show()

# %%
bike[bike['windspeed']==0.0]
# Out:
#                  datetime  season  holiday  workingday  weather   temp  \
# 0     2011-01-01 00:00:00       1        0           0        1   9.84
# 1     2011-01-01 01:00:00       1        0           0        1   9.02
# 2     2011-01-01 02:00:00       1        0           0        1   9.02
# 3     2011-01-01 03:00:00       1        0           0        1   9.84
# 4     2011-01-01 04:00:00       1        0           0        1   9.84
# ...                   ...     ...      ...         ...      ...    ...
# 10826 2012-12-17 12:00:00       4        0           1        2  16.40
# 10829 2012-12-17 15:00:00       4        0           1        2  17.22
# 10846 2012-12-18 08:00:00       4        0           1        1  15.58
# 10860 2012-12-18 22:00:00       4        0           1        1  13.94
# 10862 2012-12-19 00:00:00       4        0           1        1  12.30
#
#         atemp  humidity  windspeed  casual  registered  count  year  month  \
# ...

# %% [markdown]
# # suv파일

# %%
suv = pd.read_csv('./suv.csv',encoding='utf-8')
suv.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
suv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           400 non-null    object
#  2   Age              400 non-null    int64
#  3   EstimatedSalary  400 non-null    int64
#  4   Purchased        400 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 15.8+ KB

# %% [markdown]
# ### pd.get_dummies(데이터,columns=[])
#  - 결측값 제외하고 0,1로 구성된 더미값을 만들어줌
#  - dummy_na=True : NaN을 생성, 결측값도 인코딩해서 처리해줌

# %%
# object 인 Gender 칼럼을 0,1로 알아서 변환
suv2 = pd.get_dummies(suv,columns=['Gender'],dummy_na=True)
suv2.head()
# Out:
#     User ID  Age  EstimatedSalary  Purchased  Gender_Female  Gender_Male  \
# 0  15624510   19            19000          0              0            1
# 1  15810944   35            20000          0              0            1
# 2  15668575   26            43000          0              1            0
# 3  15603246   27            57000          0              1            0
# 4  15804002   19            76000          0              0            1
#
#    Gender_nan
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0

# %% [markdown]
# ### distplot

# %%
# Age 변수 분포 확인
f,ax=plt.subplots(figsize=(10,6))
sns.distplot(suv2['Age'])
plt.show()
# Out:
# c:\Users\user\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
f,ax=plt.subplots(figsize=(10,6))
sns.distplot(suv2['EstimatedSalary'])
plt.show()
# Out:
# c:\Users\user\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# c:\Users\user\anaconda\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
