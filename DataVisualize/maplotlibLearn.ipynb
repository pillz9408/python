# %% [markdown]
# # Maplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
y = [2,4,6]
plt.plot(y)
plt.show()

# %%
x =[1,2,3]
y =[2,4,6]
plt.plot(x,y)
plt.show()

# %% [markdown]
# ### 라인스타일
#  - ls = ''
#  - '-' : Solid line style
#  - '--': dashed ls
#  - '-.': dash-dpt
#  - ':' : dot ls

# %%
# ls =  라인스타일
x =[1,2,3]
y =[2,4,6]
plt.plot(x,y, ls = '--')
plt.show()

# %% [markdown]
# ### Marker 찍기
#  - marker = '넣고싶은 모양'

# %%
x =[1,2,3]
y =[2,4,6]
plt.plot(x,y, ls = '--', marker = 'o')
plt.show()

# %%
x =[1,2,3]
y =[2,4,6]
plt.plot(x,y, ls = '-.', marker = '*')
plt.show()

# %% [markdown]
# ### Line Width

# %%
x =[1,2,3]
y =[2,4,6]
plt.plot(x,y, ls = '-.', marker = '*', lw =5)
plt.show()

# %% [markdown]
# ### line Color

# %%
x =[1,2,3]
y =[2,4,6]
plt.plot(x,y, ls = '-.', marker = '*', lw =5, color = 'r')
plt.show()

# %% [markdown]
# ### marker color

# %%
x =[1,2,3]
y =[2,4,6]
plt.plot(x,y, ls = '-.', marker = 'o', lw =5, color = 'r',
         markerfacecolor ='b')
plt.show()

# %%
x =[1,2,3]
y =[2,4,6]
plt.plot(x,y, ls = ':', marker = '*', lw= 5, ms = 7, mec = 'k', mfc='k',mew= 5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 연습문제
x =np.arange(8)
y = [5,2,3,6,8,7,5,7]
plt.plot(x,y,ls='--' ,marker ='o', c='g' )
plt.show()

# %%
# 연습문제2
x =np.arange(8)
y = [5,2,3,6,8,7,5,7]
plt.plot(x,y,ls=':' ,marker ='D', c='r',mfc='b',mec='r' )
plt.show()

# %% [markdown]
# ### x,y 축 범위 설정
#  - plt.xlim(0,0)
#  - plt.ylim(0,0)

# %%
# 연습문제 3
x =np.arange(8)
y = [5,2,3,6,8,7,5,7]
plt.plot(x,y, ls='-.',c ='m',marker = '<',ms='10',mfc='k',mec='k' )
plt.xlim(-2,10) # x,y 축 범위 설정
plt.ylim(-5,12)
plt.show()

# %% [markdown]
# ### 그리드 그리기
#  - plt.grid()

# %%
### 그리드 그리기
x =np.arange(8)
y = [5,2,3,6,8,7,5,7]
plt.plot(x,y, ls='-.',c ='m',marker = '<',ms='10',mfc='k',mec='k' )
plt.xlim(-2,10) # x,y 축 변경
plt.ylim(-5,12)
plt.grid()
plt.show()

# %% [markdown]
# ### 틱 설정하기
#  - xticks : x축 설정
#  - yticks : y축 설정

# %%
x =np.arange(8)
y = [5,2,3,6,8,7,5,7]
plt.plot(x,y, ls='--',marker = 'o',ms='15',mew=5,mfc='r',mec='g' )
plt.xticks([0,3,6]) 
plt.yticks([1,5,9])
plt.grid()
plt.show()

# %% [markdown]
# ### 여러 개 plot 그리기

# %%
x = [1,2,3,4]
y = [2,4,6,8]
z = [3,6,9,12]
plt.plot(x, c='r')
plt.plot(y, c='g') 
plt.plot(z, c='b') 
plt.show()

# %% [markdown]
# ### 범례 표시
#  - label= ''
#  - plt.legend()

# %%
x = [1,2,3,4]
y = [2,4,6,8]
z = [3,6,9,12]
plt.plot(x, c='r',label='x')
plt.plot(y, c='g',label='y') 
plt.plot(z, c='b',label='z')
plt.legend() 
plt.show()

# %% [markdown]
# ### 차트에서 한글 보이게 하기

# %%
from matplotlib import font_manager,rc
font_name = font_manager.FontProperties(fname = 'C:/Windows/Fonts/malgun.ttf').get_name()
rc('font',family = font_name)

# %%
x = [1,2,3,4]
y = [2,4,6,8]
z = [3,6,9,12]
plt.plot(x, c='r',label='자바')
plt.plot(y, c='g',label='파이썬') 
plt.plot(z, c='b',label='시각화')
plt.legend() 
plt.show()

# %% [markdown]
# ### Title 표시
#  - plt.title()
#  - plt.xlabel()
#  - plt.ylabel()

# %%
x = [1,2,3,4]
y = [2,4,6,8]
z = [3,6,9,12]
plt.plot(x, c='r',label='자바')
plt.plot(y, c='g',label='파이썬') 
plt.plot(z, c='b',label='시각화')
plt.legend()
plt.title('범례표시')
plt.xlabel('엑스축')
plt.ylabel('와이축') 
plt.show()

# %%
# .set_rotation(원하는 각도)
x= [1,2,3,4]
y = [2,4,6,8]
z = [3,6,9,12]
plt.plot(x, c='r',label='자바')
plt.plot(y, c='g',label='파이썬') 
plt.plot(z, c='b',label='시각화')
plt.legend()
plt.title('범례표시')
plt.xlabel('엑스축')
plt.ylabel('와이축').set_rotation(1) 
plt.show()

# %%
x = np.random.randint(100, size= 100)
y = np.random.randint(100, size= 100)
plt.scatter(x,y,alpha=0.5)
plt.show()
