# %%
# 라이브러리 import
from selenium import webdriver
import time
from bs4 import BeautifulSoup as bs
import csv
import requests
import pandas as pd
import re
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities #다음화면으로 빨리 넘어갈때
from selenium.common.exceptions import UnexpectedAlertPresentException #selenium 이용시 Alert을 제어
import urllib.request
import random
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By

# %% [markdown]
# ## 네이버 View 검색을 활용한 블로그 검색
# - 스크롤 활용
# - 월 별로 1000건 제한 걸어둔 네이버

# %%
# 크롤링 시작과 끝 날짜 (달 별로 크롤링)
first_days = pd.date_range('2018/01/01','2018/12/31', freq='MS')#각 달의 첫 날
last_days = pd.date_range('2018/01/01','2018/12/31', freq='M') # 각 달의 마지막 날

keyword_list =['목소리태교','태교음악'] #검색 키워드 추가

# %%
#크롬드라이버 제어
chrome_options = Options()
chrome_options.add_argument('--no-sandbox') #bypass OS security model
chrome_options.add_argument('--disable-dex-shm-usage')#overcome limited resource
# 현재 컴큐터 크롬 드라이버 위치
chorme_path = './chromedriver.exe' #본인의 크롬 드라이버 위치 입력

# %%
#블로그 주소 수집
blog_url_list = []

#네이버에 키워드 검색
for keyword in keyword_list:
    url = 'https://search.naver.com/search.naver?sm=tab_hty.top&where=blog&query={}&oquery={}'.format(keyword, keyword)
    # 자동화된 크롬 창 실행
    driver = webdriver.Chrome(executable_path=chorme_path, options=chrome_options)
    driver.implicitly_wait(3)
    
    driver.get(url)
    time.sleep(3)
    
    url_want = 990 #한번에 1000개밖에 못긁어옴
    
    driver.find_element('xpath','//*[@id="snb"]/div[1]/div/div[2]/a').click() #검색 옵션 클릭
    
    #날짜 지정
    for k in range(len(first_days)):
        try:
            #시작과 끝의 년,월,일 설정
            driver.find_element('xpath','//*[@id="snb"]/div[2]/ul/li[3]/div/div[1]/a[9]/i').click() #직접 입력
            driver.find_element('xpath','//*[@id="snb"]/div[2]/ul/li[3]/div/div[2]/div[2]/div[1]/div/div/div/ul/li[{0}]'.format(first_days.year[k]-2002)).click()
            driver.find_element('xpath','//*[@id="snb"]/div[2]/ul/li[3]/div/div[2]/div[2]/div[2]/div/div/div/ul/li[{0}]/a'.format(first_days.month[k])).click()
            driver.find_element('xpath','//*[@id="snb"]/div[2]/ul/li[3]/div/div[2]/div[2]/div[3]/div/div/div/ul/li[{0}]/a'.format(first_days.day[k])).click()
            driver.find_element('xpath','//*[@id="snb"]/div[2]/ul/li[3]/div/div[2]/div[1]/span[3]/a').click()
            driver.find_element('xpath','//*[@id="snb"]/div[2]/ul/li[3]/div/div[2]/div[2]/div[1]/div/div/div/ul/li[{0}]'.format(last_days.year[k]-2002)).click()
            driver.find_element('xpath','//*[@id="snb"]/div[2]/ul/li[3]/div/div[2]/div[2]/div[2]/div/div/div/ul/li[{0}]/a'.format(last_days.month[k])).click()
            driver.find_element('xpath','//*[@id="snb"]/div[2]/ul/li[3]/div/div[2]/div[2]/div[3]/div/div/div/ul/li[{0}]/a'.format(last_days.day[k])).click()
            driver.find_element('xpath','//*[@id="snb"]/div[2]/ul/li[3]/div/div[2]/div[3]/button').click()
            
            #스크롤 조작
            last_height = driver.execute_script('return document.body.scrollHeight')
            
            scroll = (url_want/30)-1 #한 페이지에 기본으로 30개 글이 나옴
            
            #스크롤 다운
            for i in range(int(scroll)):
                driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')
                time.sleep(random.uniform(1,1.7))
                
                new_height = driver.execute_script('return document.body.scrollHeight')
                
                if new_height == last_height:
                    break
                last_height = new_height
                
            soup = bs(driver.page_source,'lxml')
            blog_url = soup.find_all('a', class_='api_txt_lines total_tit')
            
            #url 주소 수집
            for i in blog_url:
                blog_url_list.append(i['href']) #주소 수집
            
            print('{0} 키워드 {1}년 {2}월'.format(keyword, first_days.year[k], first_days.month[k]), len(blog_url),'개 블로그URL수집')
            
            driver.execute_script('window.scrollTo(0,0)') #수집 완료 후 스크롤 더 내려가기 방지
            
        except:
            pass
# Out:
# 목소리태교 키워드 2018년 1월 210 개 블로그URL수집
# 목소리태교 키워드 2018년 2월 205 개 블로그URL수집
# 목소리태교 키워드 2018년 3월 216 개 블로그URL수집
# 목소리태교 키워드 2018년 4월 390 개 블로그URL수집
# 목소리태교 키워드 2018년 5월 570 개 블로그URL수집
# 목소리태교 키워드 2018년 6월 390 개 블로그URL수집
# 목소리태교 키워드 2018년 7월 510 개 블로그URL수집
# 목소리태교 키워드 2018년 8월 360 개 블로그URL수집
# 목소리태교 키워드 2018년 9월 248 개 블로그URL수집
# 목소리태교 키워드 2018년 10월 150 개 블로그URL수집
# 목소리태교 키워드 2018년 11월 420 개 블로그URL수집
# 목소리태교 키워드 2018년 12월 390 개 블로그URL수집
# 태교음악 키워드 2018년 1월 226 개 블로그URL수집
# 태교음악 키워드 2018년 2월 200 개 블로그URL수집
# 태교음악 키워드 2018년 3월 217 개 블로그URL수집
# 태교음악 키워드 2018년 4월 390 개 블로그URL수집
# 태교음악 키워드 2018년 5월 600 개 블로그URL수집
# 태교음악 키워드 2018년 6월 390 개 블로그URL수집
# 태교음악 키워드 2018년 7월 480 개 블로그URL수집
# 태교음악 키워드 2018년 8월 330 개 블로그URL수집
# 태교음악 키워드 2018년 9월 276 개 블로그URL수집
# 태교음악 키워드 2018년 10월 120 개 블로그URL수집
# 태교음악 키워드 2018년 11월 360 개 블로그URL수집
# 태교음악 키워드 2018년 12월 218 개 블로그URL수집

# %%
len(blog_url_list)
# Out:
# 7866

# %%
#수집 후 URL list 중복 확인
real_list = set(blog_url_list)
blog_url_list = list(real_list)
len(blog_url_list)
# Out:
# 6472

# %%
#파일저장(블로그 주소)
k = pd.DataFrame(blog_url_list)
k.to_csv('url_list_태교.csv', encoding='utf-8-sig')

# %%
#블로그 크롤링
url = pd.read_csv('url_list_태교.csv',encoding='utf-8-sig')
blog_url_list = list(url['0'])

# %%
no_naver_blog1=[]

start = time.time()


time_list = [] #시간
review_list = [] #리뷰
comment_list = [] #댓글
like_list = [] #좋아요수
url_list = [] #url주소
count = 0

driver = webdriver.Chrome(executable_path=chorme_path, chrome_options=chrome_options) #크롬 드라이버 위치만 바꿔주시면 됩니다.
for url in blog_url_list: #기본적으로 고치지 않으시지만, n번째 크롤링에서 멈췄다면, blog_url_list를 blog_url_list[n:]으로 고칩니다.
    if 'naver' in url: #네이버 블로그만 수집(다른 사이트가 섞이면 크롤링 에러가 남)
    
        count += 1
        driver.get(url) #url 하나씩 글을 수집할꺼야
        time.sleep(1)

        try:
            # 전체 본문 가지고 와서
            driver.switch_to.frame('mainFrame') #네이버는 mainFrame을 바꿔줘야 수집이 됌
            time.sleep(1)
        
            soup = bs(driver.page_source, 'lxml') #뷰티풀숩을 이용해서 구문 분석(lxml 파싱 이용. 모든 테그에서 데이터를 추출위함)
            postview = soup.find('div', attrs={'id': re.compile('post-view.+')}).get_text()

            reg = re.compile(r'[\s+]') #r은 raw string. \s+는 공백문자
            postview_reg = reg.sub(' ',postview) #공백을 띄어쓰기로 대치해서 본문 글 수집
            try:
                # 좋아요수
                like = driver.find_element("xpath", "//span[@class='u_likeit_list_btn _button btn_sympathy pcol2 off']/em[@class='u_cnt _count']")
                like = like.text
            except:
                like = [] #좋아요 없으면 빈 리스트
            
            try:
                timeline = driver.find_element("xpath", "//span[@class='se_publishDate pcol2']") #수정 안 한 경우
        
            except:
                timeline = driver.find_element("xpath", "//p[@class='date fil5 pcol2 _postAddDate']") #수정 한 경우
            timeline = timeline.text

            try:
                driver.find_element(By.CSS_SELECTOR,'span.btn_arr').click() #댓글 내리는 버튼(태그명.클래스선택자)
                #driver.find_element_by_css_selector('span.btn_arr').click()
                time.sleep(1.7)

                comment_blog = []
                comment = driver.find_element(By.CSS_SELECTOR,'span.u_cbox_contents') #댓글
                #comment = driver.find_elements_by_css_selector('span.u_cbox_contents')
                for i in comment: #댓글 수집
                    com = str(i.text) #
                    com = reg.sub(' ',com) 
                    comment_blog.append(([com]))
            except: 
                comment_blog = []
             
            time_list.append(timeline)
            review_list.append(postview_reg)
            comment_list.append(comment_blog)
            url_list.append(url)
            like_list.append(like)
            time.sleep(random.uniform(1,1.6))
        except UnexpectedAlertPresentException:
            pass
    else:
        no_naver_blog1.append(url)
        print('네이버 블로그 아닌 url: ',url)
        
    if count%10 ==0:
        print('{}개 블로그 크롤링 완료'.format(count))
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2604\769458119.py:13: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(executable_path=chorme_path, chrome_options=chrome_options) #크롬 드라이버 위치만 바꿔주시면 됩니다.
# 10개 블로그 크롤링 완료
# 20개 블로그 크롤링 완료
# 30개 블로그 크롤링 완료
# 40개 블로그 크롤링 완료
# 50개 블로그 크롤링 완료
# 60개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://ysmlove111.tistory.com/269
# 70개 블로그 크롤링 완료
# 80개 블로그 크롤링 완료
# 90개 블로그 크롤링 완료
# 100개 블로그 크롤링 완료
# 110개 블로그 크롤링 완료
# 120개 블로그 크롤링 완료
# 130개 블로그 크롤링 완료
# 140개 블로그 크롤링 완료
# 150개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://allofthings.tistory.com/288
# 160개 블로그 크롤링 완료
# 170개 블로그 크롤링 완료
# 180개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  http://sinhwa.kr/board/46911473
# 190개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://olss.tistory.com/entry/%EC%87%BC%EB%AF%B8%EB%8D%94%EB%A8%B8%EB%8B%88777-%EB%B3%B8%EC%84%A0-%EB%B0%A9%EC%86%A1%EC%8B%9C%EC%B2%AD-%EB%A6%AC%EB%B7%B0?category=374089
# 네이버 블로그 아닌 url:  https://denl.tistory.com/entry/%ED%83%9C%EA%B5%90%EC%9D%8C%EC%95%85-%ED%81%B4%EB%9E%98%EC%8B%9D
# 네이버 블로그 아닌 url:  http://sinhwa.kr/board/69291079
# 200개 블로그 크롤링 완료
# 210개 블로그 크롤링 완료
# 220개 블로그 크롤링 완료
# 230개 블로그 크롤링 완료
# 240개 블로그 크롤링 완료
# 250개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  http://sinhwa.kr/board/18883676
# 260개 블로그 크롤링 완료
# 270개 블로그 크롤링 완료
# 280개 블로그 크롤링 완료
# 290개 블로그 크롤링 완료
# 300개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://dasony.tistory.com/1173
# 300개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  http://www.dorajistyle.pe.kr/2018/07/fetal-development-report.html
# 310개 블로그 크롤링 완료
# 320개 블로그 크롤링 완료
# 330개 블로그 크롤링 완료
# 340개 블로그 크롤링 완료
# 350개 블로그 크롤링 완료
# 360개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://gajokstory.com/1273
# 370개 블로그 크롤링 완료
# 380개 블로그 크롤링 완료
# 390개 블로그 크롤링 완료
# 400개 블로그 크롤링 완료
# 410개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://neighborgirl.tistory.com/entry/2000%EB%85%84%EB%8C%80-%ED%9E%88%ED%8A%B8%EA%B3%A1-%EB%AA%A8%EC%9D%8C
# 420개 블로그 크롤링 완료
# 430개 블로그 크롤링 완료
# 440개 블로그 크롤링 완료
# 450개 블로그 크롤링 완료
# 460개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://nextcom.tistory.com/252
# 470개 블로그 크롤링 완료
# 480개 블로그 크롤링 완료
# 490개 블로그 크롤링 완료
# 500개 블로그 크롤링 완료
# 510개 블로그 크롤링 완료
# 520개 블로그 크롤링 완료
# 530개 블로그 크롤링 완료
# 540개 블로그 크롤링 완료
# 550개 블로그 크롤링 완료
# 560개 블로그 크롤링 완료
# 570개 블로그 크롤링 완료
# 580개 블로그 크롤링 완료
# 590개 블로그 크롤링 완료
# 600개 블로그 크롤링 완료
# 610개 블로그 크롤링 완료
# 620개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://greenstar-heart.tistory.com/8
# 620개 블로그 크롤링 완료
# 630개 블로그 크롤링 완료
# 640개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://amtb.tistory.com/entry/%EB%82%99%ED%83%9C%EC%95%84-%EC%98%81%EA%B0%80%EC%B2%9C%EB%8F%84-%EC%98%81%ED%97%98%EB%8B%B4-%EB%AA%A8%EC%9D%8C
# 650개 블로그 크롤링 완료
# 660개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://alispace.tistory.com/664
# 670개 블로그 크롤링 완료
# 680개 블로그 크롤링 완료
# 690개 블로그 크롤링 완료
# 700개 블로그 크롤링 완료
# 710개 블로그 크롤링 완료
# 720개 블로그 크롤링 완료
# 730개 블로그 크롤링 완료
# 740개 블로그 크롤링 완료
# 750개 블로그 크롤링 완료
# 760개 블로그 크롤링 완료
# 770개 블로그 크롤링 완료
# 780개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  http://prismic.net/2536673413
# 790개 블로그 크롤링 완료
# 800개 블로그 크롤링 완료
# 810개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://chojien.tistory.com/1352
# 820개 블로그 크롤링 완료
# 830개 블로그 크롤링 완료
# 840개 블로그 크롤링 완료
# 850개 블로그 크롤링 완료
# 860개 블로그 크롤링 완료
# 870개 블로그 크롤링 완료
# 880개 블로그 크롤링 완료
# 890개 블로그 크롤링 완료
# 900개 블로그 크롤링 완료
# 910개 블로그 크롤링 완료
# 920개 블로그 크롤링 완료
# 930개 블로그 크롤링 완료
# 940개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://lewisnoh.tistory.com/entry/%ED%95%B5%EC%8B%AC%EA%B0%90%EC%A0%95%EC%9D%98-%EB%B3%80%ED%99%94-%EA%B3%BC%EC%A0%95
# 950개 블로그 크롤링 완료
# 960개 블로그 크롤링 완료
# 970개 블로그 크롤링 완료
# 980개 블로그 크롤링 완료
# 990개 블로그 크롤링 완료
# 1000개 블로그 크롤링 완료
# 1010개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://ilovestar44.tistory.com/69
# 1020개 블로그 크롤링 완료
# 1030개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://neighborgirl.tistory.com/entry/%EC%95%84%EA%B8%B0%EB%AC%B4%EB%A3%8C%EC%9E%90%EC%9E%A5%EA%B0%80?category=704567
# 1040개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://denl.tistory.com/entry/%EB%AA%A8%EC%A7%9C%EB%A5%B4%ED%8A%B8-%ED%83%9C%EA%B5%90%EC%9D%8C%EC%95%85-9
# 1040개 블로그 크롤링 완료
# 1050개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://jesusmedia.tistory.com/738
# 1060개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://neighborgirl.tistory.com/entry/%EC%9E%94%EC%9E%94%ED%95%9C-%EB%85%B8%EB%9E%98-%EC%97%B0%EC%86%8D%EB%93%A3%EA%B8%B0
# 1070개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  http://prismic.net/7533101873
# 1080개 블로그 크롤링 완료
# 1090개 블로그 크롤링 완료
# 1100개 블로그 크롤링 완료
# 1110개 블로그 크롤링 완료
# 1120개 블로그 크롤링 완료
# 1130개 블로그 크롤링 완료
# 1140개 블로그 크롤링 완료
# 1150개 블로그 크롤링 완료
# 1160개 블로그 크롤링 완료
# 1170개 블로그 크롤링 완료
# 1180개 블로그 크롤링 완료
# 1190개 블로그 크롤링 완료
# 1200개 블로그 크롤링 완료
# 1210개 블로그 크롤링 완료
# 1220개 블로그 크롤링 완료
# 1230개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://www.sindohblog.com/1530
# 1240개 블로그 크롤링 완료
# 1250개 블로그 크롤링 완료
# 1260개 블로그 크롤링 완료
# 1270개 블로그 크롤링 완료
# 1280개 블로그 크롤링 완료
# 1290개 블로그 크롤링 완료
# 1300개 블로그 크롤링 완료
# 1310개 블로그 크롤링 완료
# 1320개 블로그 크롤링 완료
# 1330개 블로그 크롤링 완료
# 1340개 블로그 크롤링 완료
# 1350개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://dexa.tistory.com/133
# 1360개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  http://sinhwa.kr/board/18614121
# 1370개 블로그 크롤링 완료
# 1380개 블로그 크롤링 완료
# 1390개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  http://sinhwa.kr/board/61461269
# 1390개 블로그 크롤링 완료
# 1400개 블로그 크롤링 완료
# 1410개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://jerrymom.tistory.com/79
# 1410개 블로그 크롤링 완료
# 1420개 블로그 크롤링 완료
# 1430개 블로그 크롤링 완료
# 1440개 블로그 크롤링 완료
# 1450개 블로그 크롤링 완료
# 1460개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  http://sinhwa.kr/board/28626603
# 1470개 블로그 크롤링 완료
# 1480개 블로그 크롤링 완료
# 1490개 블로그 크롤링 완료
# 1500개 블로그 크롤링 완료
# 1510개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://kalipso.github.io/2018/01/08/papa-diary-pregnant-23w/
# 1520개 블로그 크롤링 완료
# 1530개 블로그 크롤링 완료
# 1540개 블로그 크롤링 완료
# 1550개 블로그 크롤링 완료
# 1560개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://maternityschool.tistory.com/9
# 1570개 블로그 크롤링 완료
# 1580개 블로그 크롤링 완료
# 1590개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://neighborgirl.tistory.com/entry/%EB%B0%9C%EB%9D%BC%EB%93%9C-%EB%AA%85%EA%B3%A1-%EC%97%B0%EC%86%8D%EC%9E%AC%EC%83%9D
# 1600개 블로그 크롤링 완료
# 1610개 블로그 크롤링 완료
# 1620개 블로그 크롤링 완료
# 1630개 블로그 크롤링 완료
# 1640개 블로그 크롤링 완료
# 1650개 블로그 크롤링 완료
# 1660개 블로그 크롤링 완료
# 1670개 블로그 크롤링 완료
# 1680개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://chuchujung.tistory.com/172
# 1690개 블로그 크롤링 완료
# 1700개 블로그 크롤링 완료
# 1710개 블로그 크롤링 완료
# 1720개 블로그 크롤링 완료
# 1730개 블로그 크롤링 완료
# 1740개 블로그 크롤링 완료
# 1750개 블로그 크롤링 완료
# 1760개 블로그 크롤링 완료
# 1770개 블로그 크롤링 완료
# 1780개 블로그 크롤링 완료
# 1790개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://petitlog.tistory.com/426
# 네이버 블로그 아닌 url:  https://cashflow99.tistory.com/274
# 1800개 블로그 크롤링 완료
# 1810개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://dasony.tistory.com/1176
# 1820개 블로그 크롤링 완료
# 1830개 블로그 크롤링 완료
# 1840개 블로그 크롤링 완료
# 1850개 블로그 크롤링 완료
# 1860개 블로그 크롤링 완료
# 1870개 블로그 크롤링 완료
# 1880개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://fusiongugak.tistory.com/entry/%EB%B0%A9%EC%86%A1%EC%95%88%EB%82%B4-%EA%B5%AD%EC%95%85%ED%8C%9F%EC%BA%90%EC%8A%A4%ED%8A%B8-%EC%95%84%EB%A6%AC%EB%9E%91-%EC%A0%84%ED%95%B4%EC%98%A5%EC%9D%98-%EA%B5%AD%EC%95%85%EB%B8%8C%EB%A6%AC%ED%95%91-%EC%9D%B4%ED%8C%90%EC%82%AC%ED%8C%90-%EC%A0%9C3%ED%99%94-%EC%86%8C%EA%B0%9C%EA%B3%A1-%EC%A0%84%ED%98%84%EC%A0%95%EC%9D%98-%EA%B4%91%EC%A3%BC%EC%95%84%EB%A6%AC%EB%9E%91-%EC%84%B1%EC%B0%BD%EC%88%9C-%EC%84%B1%EC%A3%BC%ED%92%80%EC%9D%B4-%EA%B9%80%EC%84%B1%EB%85%80-%EC%97%B4%EB%91%90%EB%8B%AC%EC%9D%B4-%EB%8B%A4-%EC%A2%8B%EC%95%84
# 1890개 블로그 크롤링 완료
# 1900개 블로그 크롤링 완료
# 1910개 블로그 크롤링 완료
# 1920개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  http://sinhwa.kr/board/41441140
# 1930개 블로그 크롤링 완료
# 1940개 블로그 크롤링 완료
# 1950개 블로그 크롤링 완료
# 1960개 블로그 크롤링 완료
# 1970개 블로그 크롤링 완료
# 1980개 블로그 크롤링 완료
# 1990개 블로그 크롤링 완료
# 2000개 블로그 크롤링 완료
# 2010개 블로그 크롤링 완료
# 2020개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://neighborgirl.tistory.com/entry/%ED%83%9C%EA%B5%90%EC%9D%8C%EC%95%85-%ED%81%B4%EB%9E%98%EC%8B%9D?category=704567
# 2030개 블로그 크롤링 완료
# 2040개 블로그 크롤링 완료
# 2050개 블로그 크롤링 완료
# 2060개 블로그 크롤링 완료
# 2070개 블로그 크롤링 완료
# 2080개 블로그 크롤링 완료
# 2090개 블로그 크롤링 완료
# 2100개 블로그 크롤링 완료
# 2110개 블로그 크롤링 완료
# 2120개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  http://sinhwa.kr/board/50750270
# 2130개 블로그 크롤링 완료
# 2140개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://neighborgirl.tistory.com/entry/%ED%94%BC%EC%95%84%EB%85%B8-%ED%83%9C%EA%B5%90%EC%9D%8C%EC%95%85-%EB%AA%A8%EC%9D%8C?category=704567
# 2150개 블로그 크롤링 완료
# 2160개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  http://sinhwa.kr/board/91614679
# 네이버 블로그 아닌 url:  https://neighborgirl.tistory.com/entry/%EC%9D%B4%EB%A3%A8%EB%A7%88-%ED%83%9C%EA%B5%90%EC%9D%8C%EC%95%85
# 2170개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  http://sinhwa.kr/board/75826374
# 2180개 블로그 크롤링 완료
# 2190개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  http://book.interpark.com/blog/dearkyh/5025911
# 2200개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://today.blogkor.com/1750
# 2210개 블로그 크롤링 완료
# 2220개 블로그 크롤링 완료
# 2230개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  http://sinhwa.kr/board/97021899
# 2240개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://beautyya.tistory.com/entry/%ED%83%9C%EA%B5%90%EC%9D%8C%EC%95%85-%EC%B6%94%EC%B2%9C
# 2250개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://denl.tistory.com/entry/%EC%9E%84%EC%8B%A0%EC%B4%88%EA%B8%B0-%ED%83%9C%EA%B5%90%EC%9D%8C%EC%95%85-14
# 네이버 블로그 아닌 url:  https://cynicalamoeba.tistory.com/621
# 네이버 블로그 아닌 url:  https://beautyya.tistory.com/entry/%EB%AA%A8%EC%A7%9C%EB%A5%B4%ED%8A%B8-%ED%83%9C%EA%B5%90%EC%9D%8C%EC%95%85-%EA%B0%90%EB%8F%99
# 2260개 블로그 크롤링 완료
# 2270개 블로그 크롤링 완료
# 2280개 블로그 크롤링 완료
# 2290개 블로그 크롤링 완료
# 2300개 블로그 크롤링 완료
# 2310개 블로그 크롤링 완료
# 2320개 블로그 크롤링 완료
# 2330개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://ddmd.tistory.com/37
# 2340개 블로그 크롤링 완료
# 2350개 블로그 크롤링 완료
# 2360개 블로그 크롤링 완료
# 2370개 블로그 크롤링 완료
# 2380개 블로그 크롤링 완료
# 2390개 블로그 크롤링 완료
# 2400개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://dexa.tistory.com/421
# 2400개 블로그 크롤링 완료
# 2410개 블로그 크롤링 완료
# 2420개 블로그 크롤링 완료
# 2430개 블로그 크롤링 완료
# 2440개 블로그 크롤링 완료
# 2450개 블로그 크롤링 완료
# 2460개 블로그 크롤링 완료
# 2470개 블로그 크롤링 완료
# 2480개 블로그 크롤링 완료
# 2490개 블로그 크롤링 완료
# 2500개 블로그 크롤링 완료
# 2510개 블로그 크롤링 완료
# 2520개 블로그 크롤링 완료
# 2530개 블로그 크롤링 완료
# 2540개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://dexa.tistory.com/297
# 2550개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  http://sinhwa.kr/board/32920994
# 2550개 블로그 크롤링 완료
# 2560개 블로그 크롤링 완료
# 2570개 블로그 크롤링 완료
# 2580개 블로그 크롤링 완료
# 2590개 블로그 크롤링 완료
# 2600개 블로그 크롤링 완료
# 2610개 블로그 크롤링 완료
# 2620개 블로그 크롤링 완료
# 2630개 블로그 크롤링 완료
# 2640개 블로그 크롤링 완료
# 2650개 블로그 크롤링 완료
# 2660개 블로그 크롤링 완료
# 2670개 블로그 크롤링 완료
# 2680개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://byul2.tistory.com/177
# 2690개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://neighborgirl.tistory.com/entry/%EC%9E%84%EC%8B%A0%EC%B4%88%EA%B8%B0-%ED%83%9C%EA%B5%90%EC%9D%8C%EC%95%85-1
# 2700개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://abofamily.tistory.com/76
# 2700개 블로그 크롤링 완료
# 2710개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://meloyou.com/294
# 2720개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  http://blog.yes24.com/blog/blogMain.aspx?blogid=wisdomhouse&artSeqNo=10338090
# 2730개 블로그 크롤링 완료
# 2740개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://wngus82.tistory.com/318
# 2740개 블로그 크롤링 완료
# 2750개 블로그 크롤링 완료
# 2760개 블로그 크롤링 완료
# 2770개 블로그 크롤링 완료
# 2780개 블로그 크롤링 완료
# 2790개 블로그 크롤링 완료
# 2800개 블로그 크롤링 완료
# 2810개 블로그 크롤링 완료
# 2820개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://nextcom.tistory.com/235
# 2830개 블로그 크롤링 완료
# 2840개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://oxchat.tistory.com/228
# 2850개 블로그 크롤링 완료
# 2860개 블로그 크롤링 완료
# 2870개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://neighborgirl.tistory.com/entry/%EA%B0%80%EC%9D%84%EC%97%90-%EB%93%A3%EA%B8%B0%EC%A2%8B%EC%9D%80-%ED%8C%9D%EC%86%A1
# 2880개 블로그 크롤링 완료
# 2890개 블로그 크롤링 완료
# 2900개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://wngus82.tistory.com/20
# 네이버 블로그 아닌 url:  https://goodmompapa.tistory.com/35
# 2910개 블로그 크롤링 완료
# 2920개 블로그 크롤링 완료
# 2930개 블로그 크롤링 완료
# 2940개 블로그 크롤링 완료
# 2950개 블로그 크롤링 완료
# 2960개 블로그 크롤링 완료
# 2970개 블로그 크롤링 완료
# 2980개 블로그 크롤링 완료
# 2990개 블로그 크롤링 완료
# 3000개 블로그 크롤링 완료
# 3010개 블로그 크롤링 완료
# 3020개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://dexa.tistory.com/477
# 3030개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://dasony.tistory.com/1179
# 3040개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://deborah.tistory.com/2139
# 3040개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://amtb.tistory.com/entry/%EC%A4%91%EC%9D%8C%EC%8B%A0%E4%B8%AD%E9%99%B0%E8%BA%AB-%EC%A0%9C%EB%8F%84%EB%B2%95%E6%BF%9F%E5%BA%A6%E6%B3%95?category=632469
# 3050개 블로그 크롤링 완료
# 3060개 블로그 크롤링 완료
# 3070개 블로그 크롤링 완료
# 3080개 블로그 크롤링 완료
# 3090개 블로그 크롤링 완료
# 3100개 블로그 크롤링 완료
# 3110개 블로그 크롤링 완료
# 3120개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://reviewmemo.tistory.com/entry/%EC%98%81%ED%99%94%EC%9D%8C%EC%95%85-%EB%B2%A0%EC%8A%A4%ED%8A%B8-%EC%97%B0%EC%86%8D%EC%9E%AC%EC%83%9D?category=688980
# 3130개 블로그 크롤링 완료
# 3140개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://gun593132.tistory.com/9205
# 3150개 블로그 크롤링 완료
# 3160개 블로그 크롤링 완료
# 3170개 블로그 크롤링 완료
# 3180개 블로그 크롤링 완료
# 3190개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://wngus82.tistory.com/316
# 3190개 블로그 크롤링 완료
# 3200개 블로그 크롤링 완료
# 3210개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://goyangcity.tistory.com/9176
# 3220개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://rdsong.com/2320
# 네이버 블로그 아닌 url:  https://u-gamom.tistory.com/135
# 네이버 블로그 아닌 url:  https://dexa.tistory.com/260
# 3230개 블로그 크롤링 완료
# 3240개 블로그 크롤링 완료
# 3250개 블로그 크롤링 완료
# 3260개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://alarmnews.tistory.com/entry/%EA%B0%95%EB%8F%99%EB%AF%B8%EC%A6%88%EC%97%AC%EC%84%B1%EB%B3%91%EC%9B%90-%EC%98%88%EB%B9%84%EB%A7%98%EC%9D%84-%EC%9C%84%ED%95%9C-%EB%8C%80%EA%B7%9C%EB%AA%A8-%ED%83%9C%EA%B5%90%EC%9D%8C%EC%95%85%ED%9A%8C%EB%A5%BC-%EC%97%B4%EC%96%B4
# 3260개 블로그 크롤링 완료
# 3270개 블로그 크롤링 완료
# 3280개 블로그 크롤링 완료
# 3290개 블로그 크롤링 완료
# 3300개 블로그 크롤링 완료
# 3310개 블로그 크롤링 완료
# 3320개 블로그 크롤링 완료
# 3330개 블로그 크롤링 완료
# 3340개 블로그 크롤링 완료
# 3350개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://goyangcity.tistory.com/10046
# 3360개 블로그 크롤링 완료
# 3370개 블로그 크롤링 완료
# 3380개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://korea-typewriter.tistory.com/17
# 3390개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://beautyya.tistory.com/entry/%ED%83%9C%EA%B5%90%EC%9D%8C%EC%95%85-%ED%81%B4%EB%9E%98%EC%8B%9D22
# 3400개 블로그 크롤링 완료
# 3410개 블로그 크롤링 완료
# 3420개 블로그 크롤링 완료
# 3430개 블로그 크롤링 완료
# 3440개 블로그 크롤링 완료
# 3450개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://entertube.tistory.com/1232
# 3450개 블로그 크롤링 완료
# 3460개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://ndaum.tistory.com/6430
# 3470개 블로그 크롤링 완료
# 3480개 블로그 크롤링 완료
# 3490개 블로그 크롤링 완료
# 3500개 블로그 크롤링 완료
# 3510개 블로그 크롤링 완료
# 3520개 블로그 크롤링 완료
# 3530개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://snk0301.tistory.com/entry/%EC%86%A1%ED%8C%8C%EA%B5%AC%EC%82%B0%EB%B6%80%EC%9D%B8%EA%B3%BC-%EC%82%B0%EB%AA%A8%EA%B5%90%EC%9C%A1-%ED%8A%B9%EB%B3%84%ED%95%9C%EA%B2%BD%ED%97%98?category=532986
# 3540개 블로그 크롤링 완료
# 3550개 블로그 크롤링 완료
# 3560개 블로그 크롤링 완료
# 3570개 블로그 크롤링 완료
# 3580개 블로그 크롤링 완료
# 3590개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  http://sinhwa.kr/board/32694402
# 3600개 블로그 크롤링 완료
# 3610개 블로그 크롤링 완료
# 3620개 블로그 크롤링 완료
# 3630개 블로그 크롤링 완료
# 3640개 블로그 크롤링 완료
# 3650개 블로그 크롤링 완료
# 3660개 블로그 크롤링 완료
# 3670개 블로그 크롤링 완료
# 3680개 블로그 크롤링 완료
# 3690개 블로그 크롤링 완료
# 3700개 블로그 크롤링 완료
# 3710개 블로그 크롤링 완료
# 3720개 블로그 크롤링 완료
# 3730개 블로그 크롤링 완료
# 3740개 블로그 크롤링 완료
# 3750개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://yurika222.tistory.com/707
# 3750개 블로그 크롤링 완료
# 3760개 블로그 크롤링 완료
# 3770개 블로그 크롤링 완료
# 3780개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://chosege.tistory.com/84
# 3790개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://oraclejava120.tistory.com/4556
# 3800개 블로그 크롤링 완료
# 3810개 블로그 크롤링 완료
# 3820개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://ilovestar44.tistory.com/54
# 3830개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://father5.tistory.com/270
# 3840개 블로그 크롤링 완료
# 3850개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  http://book.interpark.com/blog/porque123/5100524
# 3860개 블로그 크롤링 완료
# 3870개 블로그 크롤링 완료
# 3880개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  http://blog.yes24.com/blog/blogMain.aspx?blogid=netsgo85&artSeqNo=10377302
# 3890개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://denl.tistory.com/entry/%EC%A2%8B%EC%9D%80%ED%83%9C%EA%B5%90%EC%9D%8C%EC%95%85
# 3900개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://chunwoo.tistory.com/69
# 네이버 블로그 아닌 url:  https://postie.tistory.com/entry/%ED%81%B4%EB%9E%98%EC%8B%9D-%EB%AA%85%EB%B0%98%EC%9D%84-%EC%B0%BE%EC%95%84%EC%84%9C-%EB%B9%84%EB%B0%9C%EB%94%94-%EC%A1%B0%ED%99%94%EC%9D%98-%EC%98%81%EA%B0%90-OP3-%ED%81%B4%EB%9E%98%EC%8B%9D-%EC%B6%94%EC%B2%9C
# 3910개 블로그 크롤링 완료
# 3920개 블로그 크롤링 완료
# 3930개 블로그 크롤링 완료
# 3940개 블로그 크롤링 완료
# 3950개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://lewisnoh.tistory.com/entry/%EC%82%B0%EB%A7%8C%ED%95%9C-%EC%95%84%EC%9D%B4%EB%93%A4?category=425857
# 3950개 블로그 크롤링 완료
# 3960개 블로그 크롤링 완료
# 3970개 블로그 크롤링 완료
# 3980개 블로그 크롤링 완료
# 3990개 블로그 크롤링 완료
# 4000개 블로그 크롤링 완료
# 4010개 블로그 크롤링 완료
# 4020개 블로그 크롤링 완료
# 4030개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://wngus82.tistory.com/628
# 4040개 블로그 크롤링 완료
# 4050개 블로그 크롤링 완료
# 4060개 블로그 크롤링 완료
# 4070개 블로그 크롤링 완료
# 4080개 블로그 크롤링 완료
# 4090개 블로그 크롤링 완료
# 4100개 블로그 크롤링 완료
# 4110개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  http://sinhwa.kr/board/87592962
# 4120개 블로그 크롤링 완료
# 4130개 블로그 크롤링 완료
# 4140개 블로그 크롤링 완료
# 4150개 블로그 크롤링 완료
# 4160개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://beautyya.tistory.com/entry/%ED%83%9C%EA%B5%90%EC%9D%8C%EC%95%85%EB%AC%B4%EB%A3%8C%EB%93%A3%EA%B8%B0-%E2%98%85-%EC%A0%84%EA%B3%A1%EB%93%A3%EA%B8%B0
# 4170개 블로그 크롤링 완료
# 4180개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://forcar.tistory.com/188
# 4180개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://amtb.tistory.com/entry/%EC%82%B4%EC%83%9D%EC%9D%98-%EC%9D%B8%EA%B3%BC%EC%8B%A4%ED%99%94-%EB%AA%A8%EC%9D%8C
# 4180개 블로그 크롤링 완료
# 4190개 블로그 크롤링 완료
# 4200개 블로그 크롤링 완료
# 4210개 블로그 크롤링 완료
# 4220개 블로그 크롤링 완료
# 4230개 블로그 크롤링 완료
# 4240개 블로그 크롤링 완료
# 4250개 블로그 크롤링 완료
# 4260개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://denl.tistory.com/entry/%EA%B2%8C%EC%9E%84%ED%95%A0%EB%95%8C-%EB%93%A3%EA%B8%B0-%EC%A2%8B%EC%9D%80-%EB%85%B8%EB%9E%98-2
# 4270개 블로그 크롤링 완료
# 4280개 블로그 크롤링 완료
# 4290개 블로그 크롤링 완료
# 4300개 블로그 크롤링 완료
# 4310개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://blog.hmgjournal.com/TALK/father-car-story.blg?mainYn=Y&num=39
# 4320개 블로그 크롤링 완료
# 4330개 블로그 크롤링 완료
# 4340개 블로그 크롤링 완료
# 4350개 블로그 크롤링 완료
# 4360개 블로그 크롤링 완료
# 4370개 블로그 크롤링 완료
# 4380개 블로그 크롤링 완료
# 4390개 블로그 크롤링 완료
# 4400개 블로그 크롤링 완료
# 4410개 블로그 크롤링 완료
# 4420개 블로그 크롤링 완료
# 4430개 블로그 크롤링 완료
# 4440개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://dexa.tistory.com/351
# 4450개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://wngus82.tistory.com/106
# 4460개 블로그 크롤링 완료
# 4470개 블로그 크롤링 완료
# 4480개 블로그 크롤링 완료
# 4490개 블로그 크롤링 완료
# 4500개 블로그 크롤링 완료
# 4510개 블로그 크롤링 완료
# 4520개 블로그 크롤링 완료
# 4530개 블로그 크롤링 완료
# 4540개 블로그 크롤링 완료
# 4550개 블로그 크롤링 완료
# 4560개 블로그 크롤링 완료
# 4570개 블로그 크롤링 완료
# 4580개 블로그 크롤링 완료
# 4590개 블로그 크롤링 완료
# 4600개 블로그 크롤링 완료
# 4610개 블로그 크롤링 완료
# 4620개 블로그 크롤링 완료
# 4630개 블로그 크롤링 완료
# 4640개 블로그 크롤링 완료
# 4650개 블로그 크롤링 완료
# 4660개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://sosohani.tistory.com/1886
# 4670개 블로그 크롤링 완료
# 4680개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://amtb.tistory.com/entry/%EC%A4%91%EC%9D%8C%EC%8B%A0%E4%B8%AD%E9%99%B0%E8%BA%AB-%EC%A0%9C%EB%8F%84%EB%B2%95%E6%BF%9F%E5%BA%A6%E6%B3%95-1
# 4690개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  http://sinhwa.kr/board/21398450
# 4700개 블로그 크롤링 완료
# 4710개 블로그 크롤링 완료
# 4720개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  http://webclear.co.kr/5579244584
# 4730개 블로그 크롤링 완료
# 4740개 블로그 크롤링 완료
# 4750개 블로그 크롤링 완료
# 4760개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  http://sinhwa.kr/board/47699815
# 4770개 블로그 크롤링 완료
# 4780개 블로그 크롤링 완료
# 4790개 블로그 크롤링 완료
# 4800개 블로그 크롤링 완료
# 4810개 블로그 크롤링 완료
# 4820개 블로그 크롤링 완료
# 4830개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://denl.tistory.com/entry/%EC%9E%84%EC%8B%A0%EC%B4%88%EA%B8%B0-%ED%83%9C%EA%B5%90%EC%9D%8C%EC%95%85
# 4840개 블로그 크롤링 완료
# 4850개 블로그 크롤링 완료
# 4860개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://cynicalamoeba.tistory.com/619
# 4870개 블로그 크롤링 완료
# 4880개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  http://blog.yes24.com/blog/blogMain.aspx?blogid=dongzaru&artSeqNo=10751694
# 네이버 블로그 아닌 url:  https://storykorea.tistory.com/102
# 4890개 블로그 크롤링 완료
# 4900개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://ilovestar44.tistory.com/75
# 4910개 블로그 크롤링 완료
# 4920개 블로그 크롤링 완료
# 4930개 블로그 크롤링 완료
# 4940개 블로그 크롤링 완료
# 4950개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://denl.tistory.com/entry/%ED%83%9C%EA%B5%90%EC%97%90-%EC%A2%8B%EC%9D%80-%EC%9D%8C%EC%95%85-17
# 4960개 블로그 크롤링 완료
# 4970개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://opinionx.khan.kr/entry/%EC%A0%95%EB%8F%99%EC%B9%BC%EB%9F%BC%E2%80%98%EB%AC%B8%ED%99%94%EA%B5%AD%EA%B0%80-%EC%A7%80%EB%A6%84%EA%B8%B8%E2%80%99-%EC%A0%80%EC%9E%91%EA%B6%8C%EB%B2%95-%EA%B0%9C%EC%A0%95
# 4980개 블로그 크롤링 완료
# 4990개 블로그 크롤링 완료
# 5000개 블로그 크롤링 완료
# 5010개 블로그 크롤링 완료
# 5020개 블로그 크롤링 완료
# 5030개 블로그 크롤링 완료
# 5040개 블로그 크롤링 완료
# 5050개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://poly-academy.tistory.com/1601
# 5060개 블로그 크롤링 완료
# 5070개 블로그 크롤링 완료
# 5080개 블로그 크롤링 완료
# 5090개 블로그 크롤링 완료
# 5100개 블로그 크롤링 완료
# 5110개 블로그 크롤링 완료
# 5120개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://denl.tistory.com/entry/%ED%94%BC%EC%95%84%EB%85%B8-%ED%83%9C%EA%B5%90%EC%9D%8C%EC%95%85
# 네이버 블로그 아닌 url:  https://choija.tistory.com/42
# 5130개 블로그 크롤링 완료
# 5140개 블로그 크롤링 완료
# 5150개 블로그 크롤링 완료
# 5160개 블로그 크롤링 완료
# 5170개 블로그 크롤링 완료
# 5180개 블로그 크롤링 완료
# 5190개 블로그 크롤링 완료
# 5200개 블로그 크롤링 완료
# 5210개 블로그 크롤링 완료
# 5220개 블로그 크롤링 완료
# 5230개 블로그 크롤링 완료
# 5240개 블로그 크롤링 완료
# 5250개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://fusiongugak.tistory.com/entry/6%EC%9B%94-%EC%9E%A5%EB%A5%B4%EB%8F%84-%EC%86%8C%EC%9E%AC%EB%8F%84-%EB%8B%A4%EC%96%91-%EA%B5%AD%EC%95%85-%EC%86%8C%EC%9E%AC-%EC%96%B4%EB%A6%B0%EC%9D%B4%EA%B3%B5%EC%97%B0-%EB%9F%AC%EC%8B%9C
# 5260개 블로그 크롤링 완료
# 5270개 블로그 크롤링 완료
# 5280개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://bangdoongstory.tistory.com/26
# 5290개 블로그 크롤링 완료
# 5300개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://beautyya.tistory.com/entry/%ED%81%B4%EB%9E%98%EC%8B%9D-%ED%83%9C%EA%B5%90%EC%9D%8C%EC%95%8522-1
# 5310개 블로그 크롤링 완료
# 5320개 블로그 크롤링 완료
# 5330개 블로그 크롤링 완료
# 5340개 블로그 크롤링 완료
# 5350개 블로그 크롤링 완료
# 5360개 블로그 크롤링 완료
# 5370개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://yozmidea.tistory.com/360
# 5380개 블로그 크롤링 완료
# 5390개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://dexa.tistory.com/487
# 5400개 블로그 크롤링 완료
# 5410개 블로그 크롤링 완료
# 5420개 블로그 크롤링 완료
# 5430개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://nk-rdw.tistory.com/2421
# 5440개 블로그 크롤링 완료
# 5450개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  http://blog.yes24.com/blog/blogMain.aspx?blogid=dlwpsk&artSeqNo=10860441
# 5460개 블로그 크롤링 완료
# 5470개 블로그 크롤링 완료
# 5480개 블로그 크롤링 완료
# 5490개 블로그 크롤링 완료
# 5500개 블로그 크롤링 완료
# 5510개 블로그 크롤링 완료
# 5520개 블로그 크롤링 완료
# 5530개 블로그 크롤링 완료
# 5540개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://nangjin.tistory.com/322
# 5550개 블로그 크롤링 완료
# 5560개 블로그 크롤링 완료
# 5570개 블로그 크롤링 완료
# 5580개 블로그 크롤링 완료
# 5590개 블로그 크롤링 완료
# 5600개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://onurang.tistory.com/444
# 5610개 블로그 크롤링 완료
# 5620개 블로그 크롤링 완료
# 5630개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  http://webclear.co.kr/8582556795
# 5640개 블로그 크롤링 완료
# 5650개 블로그 크롤링 완료
# 5660개 블로그 크롤링 완료
# 5670개 블로그 크롤링 완료
# 5680개 블로그 크롤링 완료
# 5690개 블로그 크롤링 완료
# 5700개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://04240418.tistory.com/16
# 5710개 블로그 크롤링 완료
# 5720개 블로그 크롤링 완료
# 5730개 블로그 크롤링 완료
# 5740개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://beautyya.tistory.com/entry/%EC%9D%B4%EB%A3%A8%EB%A7%88-%ED%83%9C%EA%B5%90%EC%9D%8C%EC%95%85%EB%93%A3%EA%B8%B0-%E2%98%85-%EC%A0%84%EA%B3%A1%EB%93%A3%EA%B8%B0
# 5740개 블로그 크롤링 완료
# 5750개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://denl.tistory.com/entry/%EB%93%A3%EA%B8%B0%EC%A2%8B%EC%9D%80-%EB%B8%8C%EA%B8%88%EB%AA%A8%EC%9D%8C
# 5760개 블로그 크롤링 완료
# 5770개 블로그 크롤링 완료
# 5780개 블로그 크롤링 완료
# 5790개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  http://webclear.co.kr/3589615571
# 5800개 블로그 크롤링 완료
# 5810개 블로그 크롤링 완료
# 5820개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://chunwoo.tistory.com/71
# 네이버 블로그 아닌 url:  https://choija.tistory.com/39
# 5830개 블로그 크롤링 완료
# 5840개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://dexa.tistory.com/495
# 5850개 블로그 크롤링 완료
# 5860개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://goyangcity.tistory.com/10546
# 5860개 블로그 크롤링 완료
# 5870개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://khori.tistory.com/entry/%EC%98%A4%EA%B0%90%EB%8F%85%EC%84%9C
# 5870개 블로그 크롤링 완료
# 5880개 블로그 크롤링 완료
# 5890개 블로그 크롤링 완료
# 5900개 블로그 크롤링 완료
# 5910개 블로그 크롤링 완료
# 5920개 블로그 크롤링 완료
# 5930개 블로그 크롤링 완료
# 5940개 블로그 크롤링 완료
# 5950개 블로그 크롤링 완료
# 5960개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://beautyya.tistory.com/entry/%EC%9E%84%EC%8B%A0-%EC%B4%88%EA%B8%B0-%ED%83%9C%EA%B5%90-%EC%9D%8C%EC%95%85%EB%93%A3%EA%B8%B0-%E2%98%85-%EC%A0%84%EA%B3%A1%EA%B0%90%EC%83%81
# 5960개 블로그 크롤링 완료
# 5970개 블로그 크롤링 완료
# 5980개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://infoletter.tistory.com/4149
# 5990개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://denl.tistory.com/entry/%ED%83%9C%EA%B5%90%EC%9D%8C%EC%95%85%EB%AC%B4%EB%A3%8C%EB%93%A3%EA%B8%B0-1
# 5990개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://andongyounggam.tistory.com/630
# 6000개 블로그 크롤링 완료
# 6010개 블로그 크롤링 완료
# 6020개 블로그 크롤링 완료
# 6030개 블로그 크롤링 완료
# 6040개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://denl.tistory.com/entry/%EB%A1%A4%ED%95%A0%EB%95%8C-%EB%93%A3%EA%B8%B0%EC%A2%8B%EC%9D%80%EB%B8%8C%EA%B8%88
# 6050개 블로그 크롤링 완료
# 6060개 블로그 크롤링 완료
# 6070개 블로그 크롤링 완료
# 6080개 블로그 크롤링 완료
# 6090개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://dexa.tistory.com/391
# 네이버 블로그 아닌 url:  https://orange2641.tistory.com/157
# 6100개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  http://soullight.egloos.com/6399364
# 6110개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://neighborgirl.tistory.com/entry/%ED%83%9C%EA%B5%90%EC%9D%8C%EC%95%85-%ED%94%BC%EC%95%84%EB%85%B8?category=704567?category=704567
# 네이버 블로그 아닌 url:  http://prismic.net/9546835741
# 6120개 블로그 크롤링 완료
# 6130개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://blogdegalleria.tistory.com/2164
# 네이버 블로그 아닌 url:  http://sinhwa.kr/board/10647265
# 6140개 블로그 크롤링 완료
# 6150개 블로그 크롤링 완료
# 6160개 블로그 크롤링 완료
# 6170개 블로그 크롤링 완료
# 6180개 블로그 크롤링 완료
# 6190개 블로그 크롤링 완료
# 6200개 블로그 크롤링 완료
# 6210개 블로그 크롤링 완료
# 6220개 블로그 크롤링 완료
# 6230개 블로그 크롤링 완료
# 6240개 블로그 크롤링 완료
# 6250개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://dasony.tistory.com/1175
# 6260개 블로그 크롤링 완료
# 6270개 블로그 크롤링 완료
# 6280개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://chunwoo.tistory.com/63
# 6290개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  http://sinhwa.kr/board/36865506
# 6300개 블로그 크롤링 완료
# 6310개 블로그 크롤링 완료

# %%
len(time_list)
# Out:
# 6316

# %%
data = {'time':time_list,
        'review':review_list,
        'like':like_list,
        'url':url_list,
        'comment': comment_list}

df = pd.DataFrame(data)

print('크롤링 소요시간', time.time()-start)
print('총 {}개 블로그 크롤링 완료!'.format(count))
df.head()
# Out:
# 크롤링 소요시간 39874.32839989662
# 총 6317개 블로그 크롤링 완료!
#                   time                                             review  \
# 0   2018. 2. 15. 16:19            루이와 마마의 산모교실           ★ 2/13일 부산 아이...
# 1    2018. 4. 23. 0:20            게시판           청주태교교실 무료임신선물 역시대세    ...
# 2    2018. 8. 7. 14:47                  노래 추천           [뉴에이지] 가을비 내릴 ...
# 3  2018. 10. 19. 17:25                  MY BABY♥           아토팜 피부교실 산모...
# 4   2018. 5. 28. 17:21            산모교실           파스퇴르 예비엄마세상 , 파스퇴르 산모...
#
#   like                                             url comment
# 0   []  https://blog.naver.com/cristalkyu/221209386996      []
# 1   []   https://blog.naver.com/d3101835q/221259057523      []
# 2    9   https://blog.naver.com/didwd0315/221334231510      []
# 3   12   https://blog.naver.com/kkhee7809/221380951576      []
# 4   []      https://blog.naver.com/bollam/221286137705      []

# %%
#csv저장
df.to_csv('18년태교.csv', encoding='utf-8-sig')
